# %% [markdown]
# # Exercise 1. Sentiment Analysis

# %% [markdown]
# **1. Using textblob, what is the probability that the sentiment in the
# Burbank text is going to negative?**

# %%
# Import necessary libraries
from textblob import TextBlob

# Open Burbank.txt file
file_path = "/content/Burbank.txt"
with open(file_path, 'r') as file:
    burbank_text = file.read()
    print('Burbank_text :','\n', burbank_text, '\n')

# Create a TextBlob object
blob = TextBlob(burbank_text)

# Get the sentiment polarity score (ranges from -1 for very negative to +1 for very positive)
sentiment_polarity = blob.sentiment.polarity
print("Sentiment polarity score : ",sentiment_polarity,'\n')

# Probability of negative sentiment
probability_neg = max(0, (1 - sentiment_polarity) / 2)
print(f"Probability of negative sentiment : {probability_neg}")
# Out:
# Burbank_text :
#  ﻿Airport task force to consider possible actions to abate noise issues Members of the Southern San Fernando Valley Airplane Noise Task Force will have a little over a month to develop recommendations about how to address aircraft noise issues affecting the south San Fernando Valley After five meetings and hearing from various neighborhood groups and experts, aviation consultant HMMH Inc., which has been the facilitator of the meetings, spent the majority of Wednesday night distilling all of the recommendations that have been brought forward so far and the feasibility of implementing them
# HMMH worked with Kevin Karpe, an aviation expert who worked as an air traffic controller at Hollywood Burbank and the Federal Aviation Administration Southern California Terminal Radar Approach Control, to analyze the departing flight procedures out of the Burbank airfield as well as Van Nuys Airport, both of which are at the center of the noise issues
# Since March 2017, residents in the south San Fernando Valley have complained about an increase in the number of planes flying overhead Many blame the FAA’s Next Generation Air Transportation System, or NextGen, which was implemented in Southern California in March 2017 The satellite-based navigation system was geared toward making flights across the country more fuel efficient and safe. However, NextGen became more of a nuisance than helpful for many people throughout the United States, according to news reports In the south San Fernando Valley, planes departing from Hollywood Burbank and Van Nuys have drifted south — from around the 101 Freeway to over Studio City and Sherman Oaks — before making northbound turns to head off to their destinations The FAA has stated in the past that NextGen did not change flight procedures out of the two airports, but HMMH and many residents from the region argue that something happened to cause the planes to make their northbound turns later rather than sooner Adam Scholten, a senior consultant with HMMH, said the workload of air traffic controllers in the Southern California TRACON, the air traffic control facility located in San Diego that is in charge of handling all of the flights in the region, may be contributing to the flight paths’ southern shift Scholten said the FAA often combines some of the six sectors of the Southern California TRACON — depending on whether there is less air traffic in one region and/or there are fewer air-traffic controllers available — a practice that can result in higher workloads “Part of the issues with combining sectors is that it can result in paying less attention to things such as standard operating procedures or other agreements that have been established,” Scholten said
# The recommended action to solve the issue, Scholten said, was for the FAA to review its resources at the Southern California TRACON and study how to manage the workload among the air-traffic controllers more efficiently The study conducted by Karpe and his consulting firm Diverse Vector Aviation Consulting LLC also found that air-traffic controllers did not always stick to the standard operating procedures for departing flights out of Hollywood Burbank and Van Nuys, which is to direct pilots to make their northbound turns once their planes meet the minimum criteria It was recommended that the FAA conduct training to refresh air-traffic controllers about the procedures HMMH also reviewed and analyzed the recommendations that were made by the various neighborhood groups Members of UproarLA, one of the groups, had suggested that departing flights should take off at a steeper ascent and make their northbound turns before reaching the 101 Freeway
# Scholten said doing so would be difficult because not every aircraft can ascend as quickly as others depending on weather conditions and the load of the plane He added that airlines can ignore the request if it isn’t made mandatory Gene Reindel, vice president and director of aviation services for HMMH, said planes ascending at a quicker and steeper rate would not be a quieter procedure for the surrounding community The organization Studio City for Quiet Skies proposed that should the FAA implement waypoints for pilots to use when departing from Hollywood Burbank, they should be located north of the 101 Freeway Scholten said this could not be done because the waypoints would be too close to the planes landing at Hollywood Burbank HMMH also showed the task force examples of possible recommendations, which did not go over well with the public They demonstrated that if the FAA implemented two waypoints to guide departing flights out of Hollywood Burbank, it would create a narrow and concentrated path above North Hollywood and the neighborhoods just south of the 101 Freeway before planes make their northbound turns The consulting firm also displayed what would happen if the current number of departing flights stayed on the path used in 2007. It resulted in a slightly less southern shift but also dispersed flights farther west toward Encino The task force will reconvene on April 1 for its final meeting, at which members of the group will deliberate on the best recommended action to address the issues The meeting will be held at 6:30 p.m. at the Los Angeles Marriott Burbank Airport, 2500 N. Hollywood Way Sixth Meeting of the Noise Task Force Held While FAA representatives sat listening with passive, stone-like faces, studies and suggested solutions were presented at the sixth meeting of the Southern San Fernando Valley Airplane Noise Task Force held Feb. 19 to discuss solutions for the ongoing problem of airliner jet noise over the Southern region of the San Fernando Valley–including the City of Burbank HMMH Inc., an environmental and transportation consulting firm, gave a detailed and lengthy presentation supplying studies, research and the pros and cons of the suggested solutions; the Task Force and community groups listened intently When HMMH confirmed air traffic from Hollywood Burbank and Van Nuys Airports had increased from 2017 to 2020, cheers and clapping erupted from the frustrated residents in the audience. Community groups have long said the extreme noise did not start until 2017 after the implementation of the FFA’s NextGen program. The NextGen satellite-based airliner navigational system, created to make flights safer, efficient and quieter, moved flight routes over the Valley from their historic paths A collective proposal by several community groups gave their own research and recommendations. Potential solutions included having planes climb to a higher altitude immediately after takeoff, dispersing flight routes in a wider range over the Valley, so no single community would suffer the bulk of jet noise and that the routes be returned to their historical paths. The FAA has said they will not return the routes to their earlier paths Beth Fulton, president of the Valley Village Homeowners Association said, “We have taken pieces of each group’s presentation and tried to figure out how is there a piece of this that can work, so everybody can try and get some relief. Our continued message is, share, share, share The FFA disqualified most of the recommendations claiming FAA regulations, limitations on airspace, airliner safety, traffic from other airports and many other explanations A newcomer to the Task Force meetings was Pacoima Beautiful representing the North East San Fernando Valley Some of the proposals that have been submitted in terms of changing flight paths is really concentrating most of the flight paths North of the airport–basically over our communities. We have a problem with that,” said Andres Ramirez, direc ...
# Several community groups from the affected areas and representatives of the local congressional districts and California’s Senators were in attendance
# Suzanne Lewis, board member of the Valley Village Neighborhood Council was direct, “You know who regulates them [FAA].  Congress. That’s who they’ll listen to. So that’s who we need to be putting pressure on. I’m glad our congressmen are here Even the senators… their representatives are here The Task Force has just under a month to recommend possible solutions to the complex issue of Valley jet noise. The next meeting of the Task Force will be April 2 at the Los Angeles Marriott Burbank Airport
#
# Sentiment polarity score :  0.09869334480780263
#
# Probability of negative sentiment : 0.45065332759609866

# %% [markdown]
# # Exercise 2. Sentiment Analysis

# %% [markdown]
# **1. Using the data from exercise 1 and textblob, what is the overall sentiment and subjectivity?**

# %%
blob.sentiment
# Out:
# Sentiment(polarity=0.09869334480780263, subjectivity=0.3790877796901893)

# %%
# Interpret sentiment polarity
# Range [-1, 1] (negative to positive)
if blob.sentiment.polarity > 0:
    print("Overall Sentiment: Positive")
elif blob.sentiment.polarity < 0:
    print("Overall Sentiment: Negative")
else:
    print("Overall Sentiment: Neutral")
print(f"Sentiment Polarity: {blob.sentiment.polarity}",'\n')

# Interpret sentiment subjectivity
# Range [0, 1] (objective to subjective)
if blob.sentiment.subjectivity > 0.5:
    print("Overall Subjectivity: Subjective")
else:
    print("Overall Subjectivity: Objective")
print(f"Sentiment Subjectivity: {blob.sentiment.subjectivity}")
# Out:
# Overall Sentiment: Positive
# Sentiment Polarity: 0.09869334480780263
#
# Overall Subjectivity: Objective
# Sentiment Subjectivity: 0.3790877796901893

# %% [markdown]
# # Exercise 3. Key topic using ‘Word’ from textblob (very simple way to determine the key topics) based on the Burbank text file.

# %% [markdown]
# **1. Import Word from textblob. Identify the key topics by using Word from textblob.**

# %%
# Download necessary resources
import nltk
nltk.download('brown')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# Import necessary libraries
from textblob import TextBlob, Word
import re
from collections import Counter
import pandas as pd

# Function to preprocess the text
def preprocess_text(text):
    # Remove special characters and numbers using regular expressions
    text = re.sub(r'[^A-Za-z\s]', '', text)
    # Convert to lowercase
    text = text.lower()
    return text

# Function to lemmatize words using Word class
def lemmatize_words(words):
    lemmatized_words = [Word(word).lemmatize() for word in words]
    return lemmatized_words

# Function to extract and lemmatize nouns from the text
def extract_nouns(text):
    blob = TextBlob(text)
    # Extract nouns using part-of-speech tagging
    nouns = [word for word, pos in blob.tags if pos == 'NN' or pos == 'NNS']
    # Lemmatize nouns using the Word class to convert plural to singular
    lemmatized_nouns = lemmatize_words(nouns)
    return lemmatized_nouns

# Function to identify the key topics based on noun frequency
def get_key_topics(nouns, top_n=10):
    # Count the frequency of each noun
    noun_counts = Counter(nouns)
    # Get the most common nouns (key topics)
    key_topics = noun_counts.most_common(top_n)
    return key_topics

# Load the Burbank text file (replace 'burbank_text.txt' with the actual file path)
with open('/content/Burbank.txt', 'r') as file:
    text = file.read()

# Preprocess the text
cleaned_text = preprocess_text(text)

# Extract and lemmatize nouns from the cleaned text
nouns = extract_nouns(cleaned_text)

# Get the top 10 key topics based on noun frequency
key_topics = get_key_topics(nouns, top_n=10)

# Create pandas dataframe and display the key topics
df = pd.DataFrame(key_topics, columns=['Phrase', 'Count'])
df.head(10)
# Out:
#            Phrase  Count
# 0          flight     15
# 1            task     10
# 2           force     10
# 3          valley     10
# 4         burbank     10
# 5           noise      9
# 6  recommendation      9
# 7           group      9
# 8           plane      9
# 9         meeting      8

# %% [markdown]
# # Exercise 4. Sentiment analysis with spaCy

# %% [markdown]
# **1. Load the datasets ‘amazon_cells_labelled.txt’, ‘imdb_labelled.txt’, ‘yelp_labelled.txt’**

# %%
# Import necessary libraries
import pandas as pd

# Load the dataset
amazon_df = pd.read_csv('/content/amazon_cells_labelled.txt', sep='\t', names=['sentence', 'label'])
amazon_df.head()
# Out:
#                                             sentence  label
# 0  So there is no way for me to plug it in here i...      0
# 1                        Good case, Excellent value.      1
# 2                             Great for the jawbone.      1
# 3  Tied to charger for conversations lasting more...      0
# 4                                  The mic is great.      1

# %%
# Load the dataset
imdb_df = pd.read_csv('/content/imdb_labelled.txt', sep='\t', names=['sentence', 'label'])
imdb_df.head()
# Out:
#                                             sentence  label
# 0  A very, very, very slow-moving, aimless movie ...      0
# 1  Not sure who was more lost - the flat characte...      0
# 2  Attempting artiness with black & white and cle...      0
# 3       Very little music or anything to speak of.        0
# 4  The best scene in the movie was when Gerardo i...      1

# %%
# Load the dataset
yelp_df = pd.read_csv('/content/yelp_labelled.txt', sep='\t', names=['sentence', 'label'])
yelp_df.head()
# Out:
#                                             sentence  label
# 0                           Wow... Loved this place.      1
# 1                                 Crust is not good.      0
# 2          Not tasty and the texture was just nasty.      0
# 3  Stopped by during the late May bank holiday of...      1
# 4  The selection on the menu was great and so wer...      1

# %% [markdown]
# **2. Create ‘combined_col’ by joining the tables such that combined_col=[data_amazon, data_imdb, data_yelp]**

# %%
# Create 'combined' as a list of data from each dataframe
combined = [amazon_df, imdb_df, yelp_df]
print(combined)
# Out:
# [                                              sentence  label
# 0    So there is no way for me to plug it in here i...      0
# 1                          Good case, Excellent value.      1
# 2                               Great for the jawbone.      1
# 3    Tied to charger for conversations lasting more...      0
# 4                                    The mic is great.      1
# ..                                                 ...    ...
# 995  The screen does get smudged easily because it ...      0
# 996  What a piece of junk.. I lose more calls on th...      0
# 997                       Item Does Not Match Picture.      0
# 998  The only thing that disappoint me is the infra...      0
# 999  You can not answer calls with the unit, never ...      0
#
# [1000 rows x 2 columns],                                               sentence  label
# 0    A very, very, very slow-moving, aimless movie ...      0
# 1    Not sure who was more lost - the flat characte...      0
# 2    Attempting artiness with black & white and cle...      0
# 3         Very little music or anything to speak of.        0
# 4    The best scene in the movie was when Gerardo i...      1
# ..                                                 ...    ...
# 743  I just got bored watching Jessice Lange take h...      0
# 744  Unfortunately, any virtue in this film's produ...      0
# 745                   In a word, it is embarrassing.        0
# 746                               Exceptionally bad!        0
# 747  All in all its an insult to one's intelligence...      0
#
# [748 rows x 2 columns],                                               sentence  label
# 0                             Wow... Loved this place.      1
# 1                                   Crust is not good.      0
# 2            Not tasty and the texture was just nasty.      0
# 3    Stopped by during the late May bank holiday of...      1
# 4    The selection on the menu was great and so wer...      1
# ..                                                 ...    ...
# 995  I think food should have flavor and texture an...      0
# 996                           Appetite instantly gone.      0
# 997  Overall I was not impressed and would not go b...      0
# 998  The whole experience was underwhelming, and I ...      0
# 999  Then, as if I hadn't wasted enough of my life ...      0
#
# [1000 rows x 2 columns]]

# %%
# Concatenate the dataframes into a single dataframe
combined_col = pd.concat([amazon_df, imdb_df, yelp_df], ignore_index=True)
combined_col.head()
# Out:
#                                             sentence  label
# 0  So there is no way for me to plug it in here i...      0
# 1                        Good case, Excellent value.      1
# 2                             Great for the jawbone.      1
# 3  Tied to charger for conversations lasting more...      0
# 4                                  The mic is great.      1

# %% [markdown]
# **3. Check the structure of data_amazon**

# %%
amazon_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   sentence  1000 non-null   object
#  1   label     1000 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 15.8+ KB

# %%
print("Null values in amazon_data : ",'\n',amazon_df.isnull().sum())
# Out:
# Null values in amazon_data :
#  sentence    0
# label       0
# dtype: int64

# %% [markdown]
# **4. Add headers for columns in each dataset: ‘Review’ and ‘Label’**

# %%
# Rename columns to 'Review' and 'Label' for each dataframe
amazon_df = amazon_df.rename(columns={'sentence': 'Review', 'label': 'Label'})
imdb_df = imdb_df.rename(columns={'sentence': 'Review', 'label': 'Label'})
yelp_df = yelp_df.rename(columns={'sentence': 'Review', 'label': 'Label'})

# %% [markdown]
# **5. Create a “Company’ column to identify each company ‘Amazon’, ‘imdb’, and ‘yelp’**

# %%
# Add a 'Company' column to each DataFrame
amazon_df['Company'] = 'Amazon'
imdb_df['Company'] = 'imdb'
yelp_df['Company'] = 'yelp'

# Now concatenate the DataFrames
comb_data = pd.concat([amazon_df, imdb_df, yelp_df], ignore_index=True)
comb_data.head()
# Out:
#                                               Review  Label Company
# 0  So there is no way for me to plug it in here i...      0  Amazon
# 1                        Good case, Excellent value.      1  Amazon
# 2                             Great for the jawbone.      1  Amazon
# 3  Tied to charger for conversations lasting more...      0  Amazon
# 4                                  The mic is great.      1  Amazon

# %% [markdown]
# **6. Explore the structure of the new dataset called ‘comb_data’**

# %%
# Explore the structure of 'comb_data'
comb_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2748 entries, 0 to 2747
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Review   2748 non-null   object
#  1   Label    2748 non-null   int64
#  2   Company  2748 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 64.5+ KB

# %%
# Check the number of rows and columns
print(comb_data.shape,'\n')

# Check the distribution of labels across different companies
print(comb_data.groupby(['Company', 'Label'])['Review'].count())
# Out:
# (2748, 3)
#
# Company  Label
# Amazon   0        500
#          1        500
# imdb     0        362
#          1        386
# yelp     0        500
#          1        500
# Name: Review, dtype: int64

# %% [markdown]
# **7. Use ‘comb_data.to_csv’ to create the ‘Sentiment_Analysis_Dataset’**

# %%
comb_data.to_csv('Sentiment_Analysis_Dataset.csv', index=False)

# %% [markdown]
# **8. Print the columns**

# %%
print(comb_data.columns)
# Out:
# Index(['Review', 'Label', 'Company'], dtype='object')

# %% [markdown]
# **9. Check for null values**

# %%
# Check for null values in each DataFrame
print("Null values in amazon_df:\n", amazon_df.isnull().sum())
print("\nNull values in imdb_df:\n", imdb_df.isnull().sum())
print("\nNull values in yelp_df:\n", yelp_df.isnull().sum())

# Check for null values in combined dataframe
print("\nNull values in comb_data:\n", comb_data.isnull().sum())
# Out:
# Null values in amazon_df:
#  Review     0
# Label      0
# Company    0
# dtype: int64
#
# Null values in imdb_df:
#  Review     0
# Label      0
# Company    0
# dtype: int64
#
# Null values in yelp_df:
#  Review     0
# Label      0
# Company    0
# dtype: int64
#
# Null values in comb_data:
#  Review     0
# Label      0
# Company    0
# dtype: int64

# %% [markdown]
# **10. Import STOP_WORDS from spacy and stopwords from spacy.lang.en.stop_words**

# %%
# Import necessary libraries
import spacy
from spacy.lang.en.stop_words import STOP_WORDS

# print stopwords
stopwords = list(STOP_WORDS)
print(stopwords)
# Out:
# ['nothing', 'somewhere', 'quite', 'down', 'this', 'via', 'whether', 'behind', 'just', 'herein', 'please', 'first', '’ll', 'nowhere', 'whither', 'the', 'noone', "'ll", 'mostly', 'another', 'hereupon', 'more', 'ours', 'several', 'make', 'namely', 'beside', 'empty', 'hence', 'would', 'somehow', 'thus', 'how', 'former', 'under', 'per', 'name', 'must', 'he', 'see', 'yourself', 'next', 'only', 'anyone', 'such', 'thru', 'seemed', 'any', 'my', 'still', 'wherever', 'it', 'everyone', 'should', 'from', 'been', '‘ll', 'whenever', 'and', 'else', 'not', 'whereby', 'as', 'doing', 'becomes', 'both', 'then', 'formerly', 'among', 'three', 'i', 'a', 'themselves', '‘re', 'anyhow', 'mine', 'thereby', 'that', 'seem', 'put', 'them', 'due', 'what', 'so', 'upon', 'full', 'after', 'however', 'all', 'go', 'often', 'many', 'give', 'either', 'even', 'for', 'together', 'herself', '’m', 'against', 'call', 'can', 'nevertheless', 'where', 'back', 'we', 'rather', 'seems', "'d", 'while', 'through', 'indeed', 'no', 'used', 'something', '‘s', 'could', 'onto', 'she', 'us', 'might', 'beyond', 'each', 'moreover', 'they', 'him', 'well', 'its', 'twelve', 'amount', 'forty', 'than', 'much', 'latter', 'around', 'may', 'below', 'elsewhere', 'also', 'along', 'none', 'almost', 'became', 'which', 'who', 'be', 'too', 'enough', 'third', 'cannot', 'others', 'eleven', 'very', 'take', 'part', 'anyway', 'to', 'wherein', 'nobody', 'move', 'same', 'meanwhile', 'during', 'seeming', 'ca', '’ve', 'although', 'have', 'in', 'always', 'had', 'on', 'besides', 'top', 'someone', 'last', 'were', 'above', 'really', 'side', 'thereupon', 'otherwise', 'once', 'using', 'hers', 'eight', 'do', 'now', 'hereafter', 'about', 'am', 'before', "n't", 'whereafter', 'or', 'n‘t', 'fifteen', 'me', 'out', 'already', 'sixty', 'whereupon', 'own', 'his', 'made', 'twenty', 'thereafter', '‘ve', 'has', 'thence', 'does', 'serious', 'fifty', 'amongst', 'becoming', 'within', 'by', 'did', 'least', 'less', 'between', 'two', 'perhaps', 'n’t', '’s', '‘d', 'further', 'her', 'nine', 'unless', 'become', 'there', 'some', 'itself', 'whom', 'various', 'everything', 'except', 'whence', 're', 'are', 'being', 'hereby', 'six', 'ten', 'alone', 'off', 'regarding', 'toward', 'towards', 'yours', 'is', '‘m', 'show', 'done', 'of', 'whose', 'ourselves', 'throughout', 'whoever', 'four', 'though', 'nor', 'but', 'hundred', 'with', 'whatever', 'keep', 'bottom', "'m", 'one', 'your', '’d', 'here', 'get', 'therein', 'our', 'yet', 'sometime', 'until', 'whereas', 'other', 'beforehand', 'anywhere', 'yourselves', 'anything', 'across', 'ever', 'every', 'you', 'if', 'was', 'since', "'s", 'everywhere', 'these', 'an', 'why', 'again', 'because', 'at', 'up', 'myself', 'when', 'afterwards', "'re", 'without', 'therefore', 'those', 'into', 'himself', '’re', 'their', 'whole', 'over', 'neither', 'few', 'latterly', 'most', "'ve", 'five', 'say', 'never', 'will', 'sometimes', 'front']

# %% [markdown]
# **11. Build a list of stopwords for filtering**

# %%
# Can add more stopwords as per our requirement
stopwords.extend(['would', 'could', 'should', 'one', 'two', 'three'])
print(stopwords)
# Out:
# ['nothing', 'somewhere', 'quite', 'down', 'this', 'via', 'whether', 'behind', 'just', 'herein', 'please', 'first', '’ll', 'nowhere', 'whither', 'the', 'noone', "'ll", 'mostly', 'another', 'hereupon', 'more', 'ours', 'several', 'make', 'namely', 'beside', 'empty', 'hence', 'would', 'somehow', 'thus', 'how', 'former', 'under', 'per', 'name', 'must', 'he', 'see', 'yourself', 'next', 'only', 'anyone', 'such', 'thru', 'seemed', 'any', 'my', 'still', 'wherever', 'it', 'everyone', 'should', 'from', 'been', '‘ll', 'whenever', 'and', 'else', 'not', 'whereby', 'as', 'doing', 'becomes', 'both', 'then', 'formerly', 'among', 'three', 'i', 'a', 'themselves', '‘re', 'anyhow', 'mine', 'thereby', 'that', 'seem', 'put', 'them', 'due', 'what', 'so', 'upon', 'full', 'after', 'however', 'all', 'go', 'often', 'many', 'give', 'either', 'even', 'for', 'together', 'herself', '’m', 'against', 'call', 'can', 'nevertheless', 'where', 'back', 'we', 'rather', 'seems', "'d", 'while', 'through', 'indeed', 'no', 'used', 'something', '‘s', 'could', 'onto', 'she', 'us', 'might', 'beyond', 'each', 'moreover', 'they', 'him', 'well', 'its', 'twelve', 'amount', 'forty', 'than', 'much', 'latter', 'around', 'may', 'below', 'elsewhere', 'also', 'along', 'none', 'almost', 'became', 'which', 'who', 'be', 'too', 'enough', 'third', 'cannot', 'others', 'eleven', 'very', 'take', 'part', 'anyway', 'to', 'wherein', 'nobody', 'move', 'same', 'meanwhile', 'during', 'seeming', 'ca', '’ve', 'although', 'have', 'in', 'always', 'had', 'on', 'besides', 'top', 'someone', 'last', 'were', 'above', 'really', 'side', 'thereupon', 'otherwise', 'once', 'using', 'hers', 'eight', 'do', 'now', 'hereafter', 'about', 'am', 'before', "n't", 'whereafter', 'or', 'n‘t', 'fifteen', 'me', 'out', 'already', 'sixty', 'whereupon', 'own', 'his', 'made', 'twenty', 'thereafter', '‘ve', 'has', 'thence', 'does', 'serious', 'fifty', 'amongst', 'becoming', 'within', 'by', 'did', 'least', 'less', 'between', 'two', 'perhaps', 'n’t', '’s', '‘d', 'further', 'her', 'nine', 'unless', 'become', 'there', 'some', 'itself', 'whom', 'various', 'everything', 'except', 'whence', 're', 'are', 'being', 'hereby', 'six', 'ten', 'alone', 'off', 'regarding', 'toward', 'towards', 'yours', 'is', '‘m', 'show', 'done', 'of', 'whose', 'ourselves', 'throughout', 'whoever', 'four', 'though', 'nor', 'but', 'hundred', 'with', 'whatever', 'keep', 'bottom', "'m", 'one', 'your', '’d', 'here', 'get', 'therein', 'our', 'yet', 'sometime', 'until', 'whereas', 'other', 'beforehand', 'anywhere', 'yourselves', 'anything', 'across', 'ever', 'every', 'you', 'if', 'was', 'since', "'s", 'everywhere', 'these', 'an', 'why', 'again', 'because', 'at', 'up', 'myself', 'when', 'afterwards', "'re", 'without', 'therefore', 'those', 'into', 'himself', '’re', 'their', 'whole', 'over', 'neither', 'few', 'latterly', 'most', "'ve", 'five', 'say', 'never', 'will', 'sometimes', 'front', 'would', 'could', 'should', 'one', 'two', 'three']

# %% [markdown]
# **12. Import string, define ‘punctuations’ and define a ‘parser’**

# %%
# Import string, define punctuations, and define a parser
import string

# Define punctuations
punctuations = string.punctuation

# Load spaCy model
nlp = spacy.load("en_core_web_sm")

# Define a parser function to filter out stopwords and punctuations
def parser(text):
    if isinstance(text, str):
        doc = nlp(text)
        return [token.text.lower() for token in doc if
            token.text.lower() not in stopwords and
            token.text not in punctuations and
            token.is_alpha]

# %% [markdown]
# **13. Tokenize the sentences**

# %%
# Apply the parser function to the 'Review' column in the DataFrame
comb_data['Review'] = comb_data['Review'].apply(lambda x: parser(x))

# Display the DataFrame with the parsed reviews
print(comb_data)
# Out:
#                                                  Review  Label Company
# 0                                [way, plug, converter]      0  Amazon
# 1                        [good, case, excellent, value]      1  Amazon
# 2                                      [great, jawbone]      1  Amazon
# 3     [tied, charger, conversations, lasting, minute...      0  Amazon
# 4                                          [mic, great]      1  Amazon
# ...                                                 ...    ...     ...
# 2743            [think, food, flavor, texture, lacking]      0    yelp
# 2744                        [appetite, instantly, gone]      0    yelp
# 2745                               [overall, impressed]      0    yelp
# 2746  [experience, underwhelming, think, ninja, sush...      0    yelp
# 2747  [wasted, life, poured, salt, wound, drawing, t...      0    yelp
#
# [2748 rows x 3 columns]

# %% [markdown]
# **14. Import ‘CountVectorizer’, ‘TfidVectorizer’, ‘accuracy_score’, ‘TransformerMixin’, ‘Pipeline’, and ‘LinearSVC’**

# %%
# Import necessary libraries
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics import accuracy_score
from sklearn.base import TransformerMixin
from sklearn.pipeline import Pipeline
from sklearn.svm import LinearSVC

# %% [markdown]
# **15. Create a class 'predictors(TransformerMixin)'. Within the class, define 'transform', 'fit', and 'get_params'**
#
# **16. Create a basic function to clean the text**

# %%
import re

# Create a class 'predictors' that extends TransformerMixin
class predictors(TransformerMixin):

    # Fit method
    def fit(self, X, y=None):
        return self

    # Transform method for cleaning the text
    def transform(self, X):
        return [self._clean_text(text) for text in X]

    # Helper function to clean the text
    def _clean_text(self, text):
        # Ensure the text is a string
        if not isinstance(text, str):
            text = str(text)

        # Remove special characters and numbers
        text = re.sub(r'[^A-Za-z\s]', '', text)
        # Convert to lowercase
        text = text.lower()
        return text


    # Get params method
    def get_params(self, deep=True):
        return {}

# %% [markdown]
# **17. Vectorize and use LinearSVC as a classifier**
#
# **18. Use TfidfVectorizer**

# %%
# Vectorize using TfidfVectorizer and classify with LinearSVC
pipe_countvect = Pipeline([
    ('cleaner', predictors()),            # Custom text cleaning
    ('vectorizer', TfidfVectorizer()),    # Vectorizer (TF-IDF)
    ('classifier', LinearSVC())           # Linear Support Vector Classifier
])

# %% [markdown]
# **19. Split the ‘com_data’ dataset into a train and test (20%) set**

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(comb_data['Review'], comb_data['Label'], test_size=0.2, random_state=17)

# %% [markdown]
# **20. Create a pipeline to clean, tokenize, vectorize, and classify as ‘pipe_countvect'**

# %%
pipe_countvect = Pipeline([
    ('cleaner', predictors()),            # Custom text cleaning
    ('vectorizer', TfidfVectorizer()),    # Vectorizer (TF-IDF)
    ('classifier', LinearSVC())           # Linear Support Vector Classifier
])

# %% [markdown]
# **21. Fit the data**

# %%
# Fit the pipeline on the training data
pipe_countvect.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('cleaner', <__main__.predictors object at 0x7e2ec580e5f0>),
#                 ('vectorizer', TfidfVectorizer()),
#                 ('classifier', LinearSVC())])

# %% [markdown]
# **22. Predict with the test dataset**

# %%
# Predict on the test dataset
y_test_pred = pipe_countvect.predict(X_test)

# %% [markdown]
# **23. Prediction results as ‘1’ for positive reviews, and ‘0’ for negative reviews**
#
# **24. Use print(sample, “Prediction➔”, pred)**

# %%
# Output the test predictions
for sample, pred in zip(X_test, y_test_pred):
    print(f"{sample} : Prediction --> {pred}")
# Out:
# [] : Prediction --> 0
# ['know', 'sounds', 'funny', 'like', 'sketchy', 'technology', 'work', 'works', 'great'] : Prediction --> 1
# ['ordered', 'voodoo', 'pasta', 'time', 'excellent', 'pasta', 'going', 'gluten', 'free', 'years', 'ago'] : Prediction --> 1
# ['music', 'mark', 'snow', 'possibly', 'best', 'score', 'heard'] : Prediction --> 1
# ['course', 'acting', 'blah'] : Prediction --> 0
# ['allowing', 'poor', 'production', 'values', 'time', 'format', 'kind', 'mini', 'series', 'baaaaaad'] : Prediction --> 0
# ['lame', 'best', 'way', 'describe'] : Prediction --> 0
# ['received', 'white', 'colored', 'battery', 'goes', 'dead', 'couple', 'hoursthe', 'original', 'week', 'lasts', 'longer', 'thereplacement'] : Prediction --> 1
# ['leave', 'theater', 'wanting', 'dance', 'stars'] : Prediction --> 0
# ['thing', 'disappoint', 'infra', 'red', 'port', 'irda'] : Prediction --> 1
# ['sashimi', 'poor', 'quality', 'soggy', 'tasteless'] : Prediction --> 0
# ['fs', 'restaurant', 'wonderful', 'breakfast', 'lunch'] : Prediction --> 1
# ['exchanged', 'phone', 'problem'] : Prediction --> 0
# ['tmobile', 'service', 'years', 'pretty', 'happy'] : Prediction --> 1
# ['premise', 'film', 'ridiculous', 'president'] : Prediction --> 0
# ['refried', 'beans', 'came', 'meal', 'dried', 'crusty', 'food', 'bland'] : Prediction --> 0
# ['generous', 'portions', 'great', 'taste'] : Prediction --> 1
# ['sound', 'clear', 'people', 'talk', 'amazed', 'quality'] : Prediction --> 1
# ['volume', 'switch', 'rocketed', 'unit', 'destination', 'unknown'] : Prediction --> 0
# ['chow', 'mein', 'good'] : Prediction --> 1
# ['makes', 'easier', 'bluetooth', 'wearing'] : Prediction --> 1
# ['good', 'food', 'vegas', 'feel', 'cheated', 'wasting', 'eating', 'opportunity', 'going', 'rice', 'company'] : Prediction --> 0
# ['horrible'] : Prediction --> 0
# ['hate', 'earbugs', 'avoid', 'phone', 'means'] : Prediction --> 0
# ['pleased'] : Prediction --> 1
# ['words', 'place', 'pretty'] : Prediction --> 0
# ['dinner', 'companions', 'told', 'fresh', 'nice', 'texture', 'taste'] : Prediction --> 1
# ['personally', 'think', 'shows', 'people', 'learn', 'find', 'compromise', 'self', 'involving', 'people', 'issue'] : Prediction --> 1
# ['reading', 'specs', 'makes', 'wow'] : Prediction --> 0
# ['waiter', 'helpful', 'friendly', 'rarely', 'checked'] : Prediction --> 0
# ['disgusted', 'pretty', 'sure', 'human', 'hair'] : Prediction --> 0
# ['mortified'] : Prediction --> 0
# ['sturdy'] : Prediction --> 1
# ['fit'] : Prediction --> 0
# ['latest', 'os', 'g', 'likes', 'slow', 'crawl', 'lock'] : Prediction --> 0
# ['places', 'eat', 'circumstances', 'return', 'tops', 'list'] : Prediction --> 0
# ['avoid', 'costs'] : Prediction --> 0
# ['great', 'sound', 'service'] : Prediction --> 1
# ['lovely', 'usual', 'cutie'] : Prediction --> 1
# ['designed', 'sharp', 'blue', 'nice', 'color'] : Prediction --> 1
# ['jabra', 'ear', 'gels', 'r', 'best'] : Prediction --> 1
# ['maintain', 'connection', 'computer', 'lap'] : Prediction --> 0
# ['overall', 'think', 'parents', 'place', 'similar', 'complaints', 'silently', 'felt'] : Prediction --> 1
# ['serve', 'indian', 'naan', 'bread', 'hummus', 'spicy', 'pine', 'nut', 'sauce', 'world'] : Prediction --> 1
# ['initially', 'local', 'sites', 'film', 'filmed', 'buffalo', 'intrigued'] : Prediction --> 1
# ['service', 'outshining', 'definitely', 'recommend', 'halibut'] : Prediction --> 1
# ['lifetime', 'air', 'knows', 'store', 'sells', 'let', 'know'] : Prediction --> 0
# ['food', 'delicious', 'spicy', 'sure', 'ask', 'spicier', 'prefer', 'way'] : Prediction --> 1
# ['good', 'stretch', 'imagination'] : Prediction --> 1
# ['month', 'worked', 'flawlessly', 'far'] : Prediction --> 1
# ['tried', 'cape', 'cod', 'ravoli', 'chicken', 'cranberry', 'mmmm'] : Prediction --> 0
# ['similarly', 'delivery', 'man', 'word', 'apology', 'food', 'minutes', 'late'] : Prediction --> 0
# ['angus', 'scrimm', 'turns', 'good', 'performance', 'somewhat', 'brief', 'memorable', 'role', 'gently', 'menacing', 'violin', 'playing', 'anatomist', 'doctor', 'quinn'] : Prediction --> 1
# ['audio', 'quality', 'poor', 'poor'] : Prediction --> 0
# ['time', 'film', 'animation', 'dominated', 'disney', 'pixar', 'cgi', 'masterpieces', 'refreshing', 'comforting', 'know', 'miyazaki', 'relying', 'traditional', 'hand', 'drawn', 'animation', 'tell', 'charming', 'enchanting', 'stories'] : Prediction --> 1
# ['del', 'taco', 'pretty', 'nasty', 'avoided', 'possible'] : Prediction --> 0
# ['returning'] : Prediction --> 0
# ['women', 'finally', 'sign', 'improvement', 'expected', 'things', 'happen', 'time', 'film', 'far', 'asleep'] : Prediction --> 1
# ['superb', 'phone', 'great', 'network'] : Prediction --> 1
# ['obviously', 'terrible', 'customer', 'service', 'pay'] : Prediction --> 0
# ['food', 'great', 'compliments', 'chef'] : Prediction --> 1
# ['disappointed', 'company'] : Prediction --> 0
# ['minutes', 'movie', 'bad'] : Prediction --> 0
# ['highly', 'recommend', 'movie', 'interested', 'art', 'poetry', 'theater', 'politics', 'japanese', 'history'] : Prediction --> 1
# ['plethora', 'salads', 'sandwiches', 'tried', 'gets', 'seal', 'approval'] : Prediction --> 1
# ['time', 'came', 'amazing', 'experience', 'tell', 'people', 'awesome', 'duck'] : Prediction --> 1
# ['barely', 'hear', 'constantly', 'saying'] : Prediction --> 0
# ['know', 'place', 'managed', 'served', 'blandest', 'food', 'eaten', 'preparing', 'indian', 'cuisine'] : Prediction --> 0
# ['watched', 'recently', 'fox', 'movie', 'channel', 'disappointed'] : Prediction --> 0
# ['excellent', 'product', 'satisfied', 'purchase'] : Prediction --> 1
# ['gone'] : Prediction --> 0
# ['m', 'surprised', 'good', 'quality', 'car', 'charger', 'reviews'] : Prediction --> 1
# ['burger', 'absolutely', 'flavor', 'meat', 'totally', 'bland', 'burger', 'overcooked', 'charcoal', 'flavor'] : Prediction --> 0
# ['drivng', 'headset', 'starts', 'ringing', 'reason'] : Prediction --> 0
# ['keypads', 'tinny', 'reach', 'wrong', 'buttons'] : Prediction --> 0
# ['kind', 'hard', 'mess', 'steak'] : Prediction --> 0
# ['wo'] : Prediction --> 0
# ['long', 'time', 'charismatic', 'actor', 'screen'] : Prediction --> 0
# ['recently', 'witnessed', 'poor', 'quality', 'management', 'guests'] : Prediction --> 0
# ['created', 'unique', 'feeling'] : Prediction --> 1
# ['told', 'people', 'happened'] : Prediction --> 0
# ['scene', 'strong', 'unpleasant'] : Prediction --> 1
# ['phone', 'dropped', 'case', 'going', 'save', 'specially', 'dropped', 'face'] : Prediction --> 0
# ['word', 'embarrassing'] : Prediction --> 0
# ['like', 'loud', 'buzzing', 'override', 'conversations', 'phone'] : Prediction --> 0
# ['works', 'great', 'cat', 'attacked', 'phone', 'scratched', 'protective', 'strip', 'instead', 'destroying', 'screen'] : Prediction --> 1
# ['stupid'] : Prediction --> 0
# ['audio', 'quality', 'poor'] : Prediction --> 0
# ['lame'] : Prediction --> 0
# ['absolute', 'visit'] : Prediction --> 1
# ['saw', 'movie', 'today', 'thought', 'good', 'effort', 'good', 'messages', 'kids'] : Prediction --> 1
# ['bluetooth', 'work', 'phone', 'locks', 'screens', 'flash', 'makes', 'calls', 'randomly', 'pocket', 'locked'] : Prediction --> 1
# ['great', 'movie'] : Prediction --> 1
# ['actually', 'smart', 'movie'] : Prediction --> 1
# ['great', 'dinners'] : Prediction --> 1
# ['tried', 'units', 'failed', 'months', 'pros'] : Prediction --> 0
# ['connected', 'wife', 'phone', 'worked', 'like', 'charm', 'phone', 'pocket', 'case'] : Prediction --> 1
# ['movie', 'cutting', 'edge'] : Prediction --> 1
# ['plug', 'work'] : Prediction --> 0
# ['need', 'mins', 'phone', 'book', 'time', 'turn', 'phone', 'battery', 'life', 'short'] : Prediction --> 0
# ['main', 'players', 'mesmerising'] : Prediction --> 1
# ['battery', 'terrible'] : Prediction --> 0
# ['plugged', 'find', 'darn', 'thing', 'worked'] : Prediction --> 0
# ['waste'] : Prediction --> 0
# ['great', 'phone'] : Prediction --> 1
# ['plus', 'paced', 'suited', 'relatively', 'short', 'run', 'time'] : Prediction --> 1
# ['device', 'great'] : Prediction --> 1
# ['highly', 'unrecommended'] : Prediction --> 1
# ['fabulous'] : Prediction --> 0
# ['said', 'acting', 'better'] : Prediction --> 1
# ['thing', 'hate', 'mode', 'set', 'button'] : Prediction --> 0
# ['suspense', 'feeling', 'frustration', 'retarded', 'girls'] : Prediction --> 1
# ['great', 'case', 'price'] : Prediction --> 1
# ['black', 'eyed', 'peas', 'sweet', 'potatoes', 'unreal'] : Prediction --> 1
# ['sets', 'especially', 'designed', 'work', 'camera', 'amazing', 'stylized', 'beautiful', 'effective'] : Prediction --> 1
# ['great', 'food', 'great', 'service', 'clean', 'friendly', 'setting'] : Prediction --> 1
# ['film'] : Prediction --> 1
# ['cool'] : Prediction --> 1
# ['movie', 'revealing'] : Prediction --> 0
# ['buy', 'buyit', 'sucks'] : Prediction --> 0
# ['ring', 'tone', 'overall', 'good', 'phone', 'buy'] : Prediction --> 1
# ['burger', 'good', 'beef', 'cooked', 'right'] : Prediction --> 1
# ['place', 'recommended', 'place'] : Prediction --> 0
# ['look', 'authentic', 'thai', 'food'] : Prediction --> 0
# ['phones', 'working', 'fine'] : Prediction --> 1
# ['crostini', 'came', 'salad', 'stale'] : Prediction --> 0
# ['plantronics', 'bluetooth', 'excelent', 'buy'] : Prediction --> 1
# ['fact', 'going', 'round', 'stars', 'awesome'] : Prediction --> 1
# ['dish', 'flavourful'] : Prediction --> 1
# ['liked', 'movie', 'way'] : Prediction --> 1
# ['design', 'ergonomic', 'theory', 'stand', 'having', 'ear'] : Prediction --> 0
# ['roast', 'beef', 'sandwich', 'tasted', 'good'] : Prediction --> 0
# ['love'] : Prediction --> 1
# ['movie', 'littered', 'overt', 'racial', 'slurs', 'black', 'cast', 'members', 'return', 'whites', 'depicted', 'morons', 'boobs'] : Prediction --> 0
# ['cases', 'tried', 'normally', 'fall', 'apart', 'months', 'long', 'haul'] : Prediction --> 1
# ['case', 'great', 'works', 'fine'] : Prediction --> 1
# ['main', 'thing', 'enjoy', 'crowd', 'older', 'crowd', 'mid'] : Prediction --> 1
# ['join', 'club', 'awesome', 'offers', 'email'] : Prediction --> 1
# [] : Prediction --> 0
# ['pretty', 'surprising', 'wonderful', 'film', 'hollywood', 'generally', 'collective', 'heads', 'sand', 'concerning', 'black', 'white', 'issues', 'time'] : Prediction --> 1
# ['wanted'] : Prediction --> 1
# ['waitress', 'friendly', 'happy', 'accomodate', 'vegan', 'veggie', 'options'] : Prediction --> 1
# ['rocked', 'world', 'certainly', 'social', 'physical', 'outlets'] : Prediction --> 1
# ['good', 'going', 'review', 'place', 'twice', 'hereas', 'tribute', 'place', 'tribute', 'event', 'held', 'night'] : Prediction --> 0
# ['construction', 'headsets', 'poor'] : Prediction --> 0
# ['damn', 'good', 'steak'] : Prediction --> 1
# ['place', 'fairly', 'clean', 'food', 'simply', 'worth'] : Prediction --> 0
# ['came', 'verizon', 'cingulair', 'nicer', 'cell', 'phones', 'thing', 'noticed', 'bad', 'service'] : Prediction --> 0
# ['got', 'sitting', 'fairly', 'fast', 'ended', 'waiting', 'minutes', 'place', 'order', 'minutes', 'food', 'arrived'] : Prediction --> 0
# ['food', 'good', 'typical', 'bar', 'food'] : Prediction --> 1
# ['different', 'minute', 'calls', 'experienced', 'drops', 'area', 'bars'] : Prediction --> 0
# ['scenes', 'oh', 'mature', 'neighbour', 'girl', 'misplace'] : Prediction --> 0
# ['day', 'week', 'different', 'deal', 'delicious'] : Prediction --> 1
# ['think', 'refill', 'water', 'struggle', 'wave', 'minutes'] : Prediction --> 0
# ['relate', 'hell', 'barely', 'understand'] : Prediction --> 0
# ['early', 'film', 'future', 'goremeister', 'lucio', 'fulci', 'good', 'addition', 'giallo', 'sub', 'genre'] : Prediction --> 1
# ['love', 'headset', 'bluetooth', 'headset', 'great', 'reception', 'good', 'ear', 'piece', 'comfortable', 'fit'] : Prediction --> 1
# ['use', 'slow', 'motion', 'needlessly', 'repeats', 'movie', 'backed', 'bad', 'acting', 'bad', 'kind', 'word', 'continuity', 'scenes', 'thrown', 'reason', 'whatsoever', 'vehicles', 'looked', 'like', 'corn', 'flakes', 'box', 'directorial', 'style', 'bordered', 'stupidity'] : Prediction --> 0
# ['food', 'came', 'good', 'pace'] : Prediction --> 1
# ['greek', 'salad', 'greek', 'dressing', 'tasty', 'pita', 'hummus', 'refreshing'] : Prediction --> 1
# ['o', 'gosh', 'best', 'phone'] : Prediction --> 1
# ['order', 'correct'] : Prediction --> 1
# ['believe', 'sequel'] : Prediction --> 0
# ['recommend'] : Prediction --> 0
# ['cinematography', 'film', 'shot', 'interesting', 'way'] : Prediction --> 1
# ['highlights', 'great', 'quality', 'nigiri'] : Prediction --> 1
# ['quit', 'working', 'months', 'purchased', 'best', 'headset', 'owned'] : Prediction --> 1
# ['weekly', 'haunt', 'definitely', 'place', 'come'] : Prediction --> 1
# ['ambiance', 'incredible'] : Prediction --> 1
# ['year', 'battery', 'went', 'completely', 'dead', 'headset'] : Prediction --> 0
# ['food', 'boring'] : Prediction --> 0
# ['enjoy', 'pizza', 'brunch'] : Prediction --> 0
# ['sounds', 'good', 'reasonably', 'priced', 'effective', 'simple'] : Prediction --> 1
# ['complaints'] : Prediction --> 1
# ['cooked', 'perfection', 'service', 'impeccable'] : Prediction --> 1
# ['works', 'like', 'charm', 'works', 'advertised'] : Prediction --> 1
# ['delivery', 'time'] : Prediction --> 0
# ['sorry', 'purchase'] : Prediction --> 0
# ['lasted', 'day', 'blew'] : Prediction --> 0
# ['plus', 'movie', 'modest', 'budget', 'fast', 'running', 'time', 'amazing', 'job'] : Prediction --> 1
# ['gross'] : Prediction --> 0
# ['pizza', 'tasted', 'old', 'super', 'chewy', 'good', 'way'] : Prediction --> 0
# ['highly', 'unprofessional', 'rude', 'loyal', 'patron'] : Prediction --> 1
# ['absolutley', 'fantastic'] : Prediction --> 1
# ['food', 'outstanding', 'prices', 'reasonable'] : Prediction --> 1
# ['buffet', 'bellagio', 'far', 'anticipated'] : Prediction --> 1
# ['weird', 'vibe', 'owners'] : Prediction --> 1
# ['monster', 'chicken', 'fried', 'steak', 'eggs', 'time', 'favorite'] : Prediction --> 0
# ['hypocrisy', 'film', 'vomit'] : Prediction --> 1
# ['camera', 'phone', 'dustpan', 'indoors', 'disposable'] : Prediction --> 1
# ['features', 'want'] : Prediction --> 1
# ['father', 'battery', 'dying'] : Prediction --> 1
# ['close', 'house', 'low', 'key', 'non', 'fancy', 'affordable', 'prices', 'good', 'food'] : Prediction --> 1
# ['horrible', 'phone'] : Prediction --> 0
# ['equally', 'awful'] : Prediction --> 0
# ['treated', 'equally', 'special'] : Prediction --> 0
# ['took', 'money', 'got', 'outta'] : Prediction --> 0
# ['far', 'visited', 'twice', 'food', 'absolutely', 'delicious', 'time'] : Prediction --> 1
# ['incredible', 'soundtrack', 'truly', 'captures', 'essence', 'film'] : Prediction --> 1
# ['headphones', 'great', 'find', 'think', 'best', 'purchase', 'years', 'seriously'] : Prediction --> 1
# ['attractive', 'set', 'film', 'eye', 'pleasing', 'gem'] : Prediction --> 1
# ['nt', 'wrong', 'food'] : Prediction --> 0
# ['fun', 'funny', 'movie'] : Prediction --> 1
# ['wo', 'disappointed'] : Prediction --> 0
# ['voice', 'quality', 'signal', 'strength', 'dropped', 'calls'] : Prediction --> 0
# ['knew', 'saw', 'film', 'great', 'things', 'come', 'gifted', 'actor'] : Prediction --> 1
# ['sushi', 'strip', 'place'] : Prediction --> 0
# ['presentation', 'food', 'awful'] : Prediction --> 0
# ['sets', 'bad', 'look', 'place', 'thunderbirds', 'episode'] : Prediction --> 0
# ['elias', 'koteas', 'jack', 'palance', 'play', 'good', 'roles', 'angelina', 'hot', 'gets', 'naked', 'billy', 'drago', 'appears', 'cool', 'usual', 'cameo', 'sven', 'ole', 'thorsen', 'helps', 'enjoyable', 'movie', 'good', 'acting', 'decent', 'budget'] : Prediction --> 1
# ['performed'] : Prediction --> 0
# ['bread', 'house'] : Prediction --> 1
# ['seller', 'understanding', 'patient', 'definitely', 'buy'] : Prediction --> 1
# ['worthless', 'product'] : Prediction --> 0
# ['recommended', 'friends'] : Prediction --> 0
# ['good', 'film', 'great', 'unconditional', 'love'] : Prediction --> 1
# ['small', 'worth', 'price'] : Prediction --> 1
# ['fantastic', 'thai', 'restaurant', 'definitely', 'worth', 'visit'] : Prediction --> 1
# ['looking', 'good', 'quality', 'motorola', 'headset', 'looking'] : Prediction --> 0
# ['picture', 'battery', 'drops', 'bar', 'starts', 'beeping', 'letting', 'know', 'dieing'] : Prediction --> 0
# ['want', 'money'] : Prediction --> 0
# ['wind', 'resistant'] : Prediction --> 1
# ['hopefully', 'director', 'james', 'cox', 'turn', 'short', 'feature', 'length', 'film', 'cast', 'win', 'new', 'film'] : Prediction --> 1
# ['store', 'bought', 'new', 'nokia', 'phone', 'working', 'great'] : Prediction --> 0
# ['terribly', 'disappointed', 'film', 'receive', 'awards', 'accolades', 'especially', 'far', 'deserving', 'works', 'film'] : Prediction --> 1
# ['got', 'car', 'charger', 'week', 'charger', 'broken', 'went', 'plug', 'started', 'smoking'] : Prediction --> 0
# ['unfortunately', 'ability', 'actually', 'know', 'receiving', 'important', 'feature', 'phone', 'pitiful', 'respect'] : Prediction --> 0
# ['realize', 'wonderful', 'short', 'scenes'] : Prediction --> 1
# ['good', 'product', 'good', 'seller'] : Prediction --> 1
# ['server', 'super', 'nice', 'checked', 'times'] : Prediction --> 1
# ['unfortunately', 'recharge', 'iphone', 'despite', 'connecting', 'multiple', 'power', 'sources', 'imac', 'external', 'battery', 'wall', 'outlet', 'etc'] : Prediction --> 0
# ['waste', 'bucks'] : Prediction --> 0
# ['rude', 'inconsiderate', 'management'] : Prediction --> 0
# ['wants', 'surf', 'small', 'wave', 'space', 'movies', 'deep', 'impact', 'armageddon', 'fails'] : Prediction --> 0
# ['trying', 'return', 'refund'] : Prediction --> 0
# ['different', 'occasions', 'asked', 'medium', 'times', 'got', 'bloodiest', 'piece', 'meat', 'plate'] : Prediction --> 0
# ['film', 'redeeming', 'features'] : Prediction --> 1
# ['ordered', 'appetizer', 'took', 'minutes', 'pizza', 'minutes'] : Prediction --> 0
# ['awful'] : Prediction --> 0
# ['stars', 'brick', 'oven', 'bread', 'app'] : Prediction --> 1
# ['clear', 'range', 'ability', 'pull'] : Prediction --> 1
# ['frozen', 'pucks', 'disgust', 'worst', 'people', 'register'] : Prediction --> 0
# ['best', 'bluetooth', 'market'] : Prediction --> 1
# ['steamboat', 'willie', 'amazingly', 'important', 'film', 'cinema', 'history'] : Prediction --> 1
# ['cases', 'order'] : Prediction --> 1
# ['awesome', 'selection', 'beer'] : Prediction --> 1
# ['close', 'ups'] : Prediction --> 1
# ['food', 'amazing'] : Prediction --> 1
# ['great', 'time', 'dos', 'gringos'] : Prediction --> 1
# ['hot', 'sour', 'egg', 'flower', 'soups', 'absolutely', 'stars'] : Prediction --> 0
# ['ordered', 'toasted', 'english', 'muffin', 'came', 'untoasted'] : Prediction --> 0
# ['fries', 'great'] : Prediction --> 1
# ['unfortunately', 'cover', 'girl', 'example', 'hollywood', 'exploit', 'women', 'financial', 'gain'] : Prediction --> 0
# ['earpiece', 'large', 'heavy', 'keeps', 'falling', 'ear'] : Prediction --> 0
# ['arguing', 'verizon', 'dropped', 'calls', 'returned', 'phones', 'days'] : Prediction --> 0
# ['useless', 'phone', 'simply', 'deaf'] : Prediction --> 0
# ['recommend'] : Prediction --> 0
# ['certainly', 'mean', 'distinction', 'good', 'way'] : Prediction --> 1
# ['stay', 'away', 'shrimp', 'stir', 'fried', 'noodles'] : Prediction --> 0
# ['great', 'place', 'relax', 'awesome', 'burger', 'beer'] : Prediction --> 1
# ['new', 'fav', 'vegas', 'buffet', 'spot'] : Prediction --> 1
# ['bad', 'bad'] : Prediction --> 0
# ['acted', 'tv', 'movie'] : Prediction --> 1
# ['like', 'crepe', 'station'] : Prediction --> 1
# ['barely', 'boring', 'moment', 'film', 'plenty', 'humorous', 'parts'] : Prediction --> 1
# ['assure', 'wo', 'disappointed'] : Prediction --> 0
# ['delete', 'film', 'mind'] : Prediction --> 1
# ['live', 'music', 'fridays', 'totally', 'blows'] : Prediction --> 0
# ['lewis', 'black', 'considerable', 'talent', 'wasted', 'incendiary', 'unrestrained', 'rating', 'certainly', 'wo', 'allow'] : Prediction --> 0
# ['whine', 'internet', 'goes', 'use', 'thing', 'like'] : Prediction --> 0
# ['adorable', 'seeing', 'mickey', 'playing', 'turkey', 'straw', 'highly', 'imaginative', 'occasionally', 'cruel', 'way'] : Prediction --> 1
# ['eaten', 'multiple', 'times', 'time', 'food', 'delicious'] : Prediction --> 1
# ['satisfied', 'cell', 'phone', 'day'] : Prediction --> 1
# ['time', 'wait'] : Prediction --> 0
# ['love', 'place', 'hits', 'spot', 'want', 'healthy', 'lacking', 'quantity', 'flavor'] : Prediction --> 1
# ['lousy', 'product'] : Prediction --> 0
# ['poor', 'sound', 'quality'] : Prediction --> 0
# ['worked'] : Prediction --> 0
# ['highly', 'doubt', 'like', 'trash'] : Prediction --> 1
# ['jerks', 'phone'] : Prediction --> 0
# ['guess', 'maybe', 'went', 'night', 'disgraceful'] : Prediction --> 0
# ['food', 'terrible'] : Prediction --> 0
# ['find', 'movie', 'intelligent', 'masterful', 'intelligence', 'imagination', 'obviously', 'try', 'sense', 'pitiful', 'attempt', 'human', 'nature', 'try', 'sense', 'things'] : Prediction --> 0
# ['know', 'exactly', 'movie', 'latched', 'endearing', 'movie', 'special', 'family', 'memories'] : Prediction --> 1
# ['phone', 'got', 'year', 'old', 'slowly', 'breaking', 'despite', 'care'] : Prediction --> 0
# ['uncomfortable', 'ear', 'use', 'lg', 'env'] : Prediction --> 0
# ['came', 'today', 'relocated', 'impressed'] : Prediction --> 1
# ['pictures', 'case', 'lense', 'covered'] : Prediction --> 1
# ['believe', 'pitch', 'black'] : Prediction --> 0
# ['easy', 'install', 'use', 'clear', 'sound'] : Prediction --> 1
# ['especially', 'love', 'long', 'battery', 'life'] : Prediction --> 1
# ['orders', 'tacos', 'think', 'customer', 'service', 'ask', 'combo', 'ala', 'cart'] : Prediction --> 1
# ['watched', 'sundays', 'ago', 'march', 'began', 'enjoy', 'time', 'taped', 'entire', 'thing'] : Prediction --> 0
# ['best', 'luck', 'rude', 'non', 'customer', 'service', 'focused', 'new', 'management'] : Prediction --> 0
# ['highly', 'recommend', 'device'] : Prediction --> 1
# ['wind', 'lion', 'told', 'largely', 'eyes', 'son', 'member', 'family', 'identify', 'characters', 'sean', 'connery', 'noble', 'brigand', 'candace', 'bergen', 'feisty', 'heroine', 'john', 'huston', 'wily', 'john', 'hay', 'steve', 'kanaly', 'spiffy', 'radiant', 'ruthless', 'lieutenant', 'roosevelt', 'big', 'stick'] : Prediction --> 1
# ['great', 'new', 'packaged', 'nice', 'works', 'good', 'problems', 'came', 'time', 'expected'] : Prediction --> 1
# ['love', 'scream', 'movies', 'horror', 'movies', 'ranks', 'way'] : Prediction --> 1
# ['tracfonewebsite', 'user', 'friendly', 'makes', 'easy', 'toactivate', 'etc'] : Prediction --> 1
# ['thing', 'tolerate', 'political', 'incorrectness', 'artistic', 'freedom', 'suspension', 'disbelief', 'slavic', 'female', 'character'] : Prediction --> 1
# ['purcashed', 'car', 'charger', 'work'] : Prediction --> 0
# ['poor', 'service'] : Prediction --> 0
# ['attempting', 'artiness', 'black', 'white', 'clever', 'camera', 'angles', 'movie', 'disappointed', 'ridiculous', 'acting', 'poor', 'plot', 'lines', 'non', 'existent'] : Prediction --> 0
# ['place', 'gyros'] : Prediction --> 0
# ['thing', 'worse', 'taylor', 'acting', 'stanwyck', 'singing'] : Prediction --> 0
# ['bus', 'boy', 'hand', 'rude'] : Prediction --> 0
# ['eclectic', 'selection'] : Prediction --> 0
# ['piece', 'junk', 'broke', 'phone', 'days'] : Prediction --> 0
# ['work'] : Prediction --> 0
# ['case', 'extra', 'originally', 'later', 'discarded', 'scratched', 'ear'] : Prediction --> 1
# ['good', 'time'] : Prediction --> 1
# ['stories', 'unbelievable', 'actors'] : Prediction --> 1
# ['sure', 'order', 'dessert', 'need', 'pack', 'tiramisu', 'cannoli', 'die'] : Prediction --> 1
# ['inside', 'nice', 'clean'] : Prediction --> 1
# ['results', 'shame'] : Prediction --> 0
# ['impressed', 'recommend', 'item'] : Prediction --> 0
# ['usually', 'like', 'headbands', 'lightweight', 'mess', 'hair'] : Prediction --> 0
# ['buy', 'want', 'use', 'holster'] : Prediction --> 0
# ['lately', 'extremely', 'nice', 'helpful', 'phone'] : Prediction --> 1
# ['scenes', 'funny', 'occasionally', 'touching', 'characters', 'evaluate', 'lives', 'going'] : Prediction --> 1
# ['love', 'great', 'armband'] : Prediction --> 1
# ['disappointed'] : Prediction --> 0
# ['bought', 'hoping', 'bluetooth', 'headset', 'fit', 'better', 'things', 'impossible', 'wear'] : Prediction --> 1
# ['con', 'spotty', 'service'] : Prediction --> 0
# ['lobster', 'bisque', 'bussell', 'sprouts', 'risotto', 'filet', 'needed', 'salt', 'pepper', 'course', 'tables'] : Prediction --> 0
# ['deserves', 'stars'] : Prediction --> 0
# ['joy', 'use'] : Prediction --> 1
# ['end', 'days', 'worst', 'big', 'budget', 'action', 'movies', 'seen'] : Prediction --> 0
# ['conclusion', 'bother', 'movie', 'volcano', 'los', 'angeles', 'nonsense'] : Prediction --> 0
# ['waited', 'hour', 'breakfast', 'times', 'better', 'home'] : Prediction --> 0
# ['bought', 'wired', 'headphones', 'sound', 'better'] : Prediction --> 0
# ['ps', 'scene', 'movie', 'cool', 'central', 'character', 'finds', 'room', 'blown'] : Prediction --> 1
# ['high', 'quality', 'chicken', 'chicken', 'caesar', 'salad'] : Prediction --> 0
# ['pros', 'large', 'seating', 'nice', 'bar', 'great', 'simple', 'drink', 'best', 'brick', 'oven', 'pizza', 'homemade', 'dough'] : Prediction --> 1
# ['loved', 'bacon', 'wrapped', 'dates'] : Prediction --> 1
# ['loved', 'grilled', 'pizza', 'reminded', 'legit', 'italian', 'pizza'] : Prediction --> 1
# ['entire', 'audience', 'applauded', 'conclusion', 'film'] : Prediction --> 1
# ['times', 'bad', 'customer', 'service'] : Prediction --> 0
# ['great', 'choice'] : Prediction --> 1
# ['fella', 'got', 'huevos', 'rancheros', 'look', 'appealing'] : Prediction --> 0
# ['bad', 'experience'] : Prediction --> 0
# ['finally', 'times', 'spring', 'latch', 'broke', 'use', 'longer', 'visor'] : Prediction --> 0
# ['glad', 'purchased'] : Prediction --> 1
# ['like', 'fact', 'rests', 'lightly', 'ear', 'inside'] : Prediction --> 1
# ['excellent', 'dual', 'purpose', 'headset'] : Prediction --> 1
# ['art', 'style', 'appearance', 'crayon', 'pencil', 'drawings', 'wonderfully', 'colorful', 'fanciful'] : Prediction --> 1
# ['received', 'supposedly', 'new', 'motorola', 'apparently', 'match', 'phone', 'charger'] : Prediction --> 0
# ['given', 'godfathers', 'zero', 'stars', 'possible'] : Prediction --> 0
# ['goat', 'taco', 'skimp', 'meat', 'wow', 'flavor'] : Prediction --> 0
# ['buy', 'product', 'fails'] : Prediction --> 0
# ['phone', 'worst', 'brand'] : Prediction --> 0
# ['note', 'ventilation', 'use', 'upgrading'] : Prediction --> 0
# ['way', 'plug', 'converter'] : Prediction --> 0
# ['looking', 'headset', 'long', 'time', 'got', 'happier'] : Prediction --> 0
# ['fantastic', 'earphones'] : Prediction --> 1
# ['definately', 'enjoyed'] : Prediction --> 1
# ['wanted', 'plantronics', 'right', 'issues', 'good'] : Prediction --> 1
# ['great', 'deal'] : Prediction --> 1
# ['works', 'buy'] : Prediction --> 1
# ['readers', 'seen', 'miyazaki', 'films', 'form', 'worthwhile', 'experience'] : Prediction --> 1
# ['high', 'hopes', 'place', 'burgers', 'cooked', 'charcoal', 'grill', 'unfortunately', 'taste', 'fell', 'flat', 'way', 'flat'] : Prediction --> 0
# ['food', 'average'] : Prediction --> 0
# ['phone', 'crashed', 'completely', 'replaced'] : Prediction --> 0
# ['sweet', 'potato', 'tots', 'good', 'onion', 'rings', 'perfection', 'close'] : Prediction --> 1
# ['days', 'easy', 'hear'] : Prediction --> 1
# ['best', 'headset'] : Prediction --> 1
# ['place', 'like', 'chipotle', 'better'] : Prediction --> 1
# ['know', 'wise', 'decision'] : Prediction --> 0
# ['found', 'product', 'easy', 'set', 'use'] : Prediction --> 1
# ['camera', 'rated', 'impressive', 'megapixels', 'renders', 'images', 'fall', 'expectations', 'relatively', 'high', 'resolution'] : Prediction --> 0
# ['writers', 'smack', 'think', 'best', 'actors', 'actresses', 'bonus', 'characters', 'real'] : Prediction --> 1
# ['conclusion', 'loved'] : Prediction --> 1
# ['success', 'film', 'depends', 'casting', 'sydney', 'greenstreet', 'alexander', 'yardley', 'character'] : Prediction --> 1
# ['definitely', 'worth', 'checking'] : Prediction --> 1
# ['seen', 'movie', 'definitely', 'recommend'] : Prediction --> 0
# ['excellently', 'produced', 'sci', 'fi', 'best', 'producers', 'scot', 'vandiver'] : Prediction --> 1
# ['service', 'cute'] : Prediction --> 1
# ['breakfast', 'perpared', 'great', 'beautiful', 'presentation', 'giant', 'slices', 'toast', 'lightly', 'dusted', 'powdered', 'sugar'] : Prediction --> 1
# ['warn', 'rent', 'movie', 'dumbest', 'thing', 'seen'] : Prediction --> 1
# ['plot', 'holes', 'pair', 'fishnet', 'stockings', 'direction', 'editing', 'astonishingly', 'ham', 'fisted'] : Prediction --> 0
# ['service', 'slow', 'attentive'] : Prediction --> 0
# ['oh', 'forgot', 'mention', 'weird', 'color', 'effect', 'phone'] : Prediction --> 1
# ['script', 'looks', 'rough', 'draft', 'written', 'shooting', 'began', 'finished', 'script', 'completed'] : Prediction --> 0
# ['purchase', 'different', 'case'] : Prediction --> 1
# ['deeply', 'impressed', 'character', 'played'] : Prediction --> 1
# ['plantronincs', 'continues', 'use', 'flawed', 'charger', 'design'] : Prediction --> 0
# ['high', 'adventure', 'best'] : Prediction --> 1
# ['macbeth', 'jason', 'connery', 'moved', 'tears', 'final', 'monolog', 'brief', 'candle', 'gave', 'sphere', 'moral', 'decay', 'dark', 'forces', 'human', 'face', 'makes', 'interesting'] : Prediction --> 1
# ['waste', 'money'] : Prediction --> 0
# ['pleasant', 'voyage', 'self', 'discovery'] : Prediction --> 0
# ['fries', 'doubt', 'worst', 'fries'] : Prediction --> 0
# ['americans', 'stupid', 'hatred', 'clichés', 'admitted'] : Prediction --> 0
# ['good', 'price'] : Prediction --> 1
# ['design', 'odd', 'ear', 'clip', 'comfortable'] : Prediction --> 1
# ['beat'] : Prediction --> 1
# ['comfortable', 'hand'] : Prediction --> 1
# ['brother', 'law', 'works', 'mall', 'ate', 'day', 'guess', 'sick', 'night'] : Prediction --> 0
# ['super', 'charged', 'use', 'small', 'hybrid', 'palmtop', 'camera', 'cellphone', 'excels', 'roles'] : Prediction --> 1
# ['seafood', 'limited', 'boiled', 'shrimp', 'crab', 'legs', 'crab', 'legs', 'definitely', 'taste', 'fresh'] : Prediction --> 1
# ['mic', 'joke', 'volume', 'low'] : Prediction --> 0
# ['mac', 'salad', 'pretty', 'bland', 'getting'] : Prediction --> 0
# ['cool', 'cases', 'open', 'allowing', 'screen', 'scratched'] : Prediction --> 1
# ['jabra', 'earset', 'happy', 'sound', 'quality', 'especially', 'outgoing', 'better'] : Prediction --> 1
# ['good', 'product', 'incredible', 'value'] : Prediction --> 1
# ['sweet', 'potato', 'fries', 'good', 'seasoned'] : Prediction --> 1
# ['highly', 'recommend', 'product'] : Prediction --> 1
# ['awful'] : Prediction --> 0
# ['saggy', 'floppy', 'piece', 'junk'] : Prediction --> 0
# ['vegas', 'buffet', 'disappoint'] : Prediction --> 1
# ['chosen', 'tortured', 'disgusting', 'piece', 'blatant', 'american', 'propaganda'] : Prediction --> 0
# ['worse', 'humiliated', 'worker', 'right', 'bunch', 'horrible', 'callings'] : Prediction --> 0
# ['place'] : Prediction --> 0
# ['grilled', 'chicken', 'tender', 'yellow', 'saffron', 'seasoning'] : Prediction --> 1
# ['fan', 'movie', 'sucked', 'bad'] : Prediction --> 0
# ['recommend', 'faceplates', 'looks', 'nice', 'elegant', 'cool'] : Prediction --> 1
# ['service', 'fantastic'] : Prediction --> 1
# ['great', 'product'] : Prediction --> 1
# ['husband', 'said', 'rude', 'apologize', 'bad', 'food'] : Prediction --> 0
# ['real', 'sushi', 'lovers', 'let', 'honest', 'yama', 'good'] : Prediction --> 0
# ['disappointing', 'dinner', 'went', 'dessert'] : Prediction --> 0
# ['check', 'voice', 'mail', 'night', 'keypad', 'backlight', 'turns', 'seconds', 'message', 'lost'] : Prediction --> 1
# ['highly', 'recommend'] : Prediction --> 1
# [] : Prediction --> 0
# ['hate', 'movies', 'like'] : Prediction --> 0
# ['good'] : Prediction --> 1
# ['think', 'going', 'anytime', 'soon'] : Prediction --> 0
# ['heard', 'cole', 'totally', 'unbelievable'] : Prediction --> 0
# ['understand', 'garbage', 'got', 'shelves', 'movie', 'store', 'real', 'movie'] : Prediction --> 0
# ['bucks', 'head', 'expect', 'better', 'food'] : Prediction --> 1
# ['liked'] : Prediction --> 1
# ['showed', 'exactly', 'government', 'scientist', 'argued', 'humanity', 'reasons', 'gadget'] : Prediction --> 1
# ['great', 'way', 'finish', 'great'] : Prediction --> 1
# ['waitress', 'little', 'slow', 'service'] : Prediction --> 0
# ['terrible', 'product', 'waste', 'money'] : Prediction --> 0
# ['pleasure', 'dealing'] : Prediction --> 0
# ['week', 'later', 'activated', 'suddenly', 'died'] : Prediction --> 0
# ['zero', 'stars', 'zero', 'stars'] : Prediction --> 0
# ['volume'] : Prediction --> 0
# ['food', 'amazing'] : Prediction --> 1
# ['bad', 'pay', 'month', 'service'] : Prediction --> 0
# ['good', 'food', 'great'] : Prediction --> 1
# ['good', 'hoped'] : Prediction --> 1
# ['setup', 'went', 'smoothly'] : Prediction --> 1
# ['regular', 'toasted', 'bread', 'equally', 'satisfying', 'occasional', 'pats', 'butter', 'mmmm'] : Prediction --> 1
# ['recommend', 'saving', 'room'] : Prediction --> 0
# ['phone', 'bought', 'wow'] : Prediction --> 0
# ['poor', 'batter', 'meat', 'ratio', 'chicken', 'tenders', 'unsatisfying'] : Prediction --> 0
# ['magical', 'help'] : Prediction --> 0
# ['think', 'gone', 'movie', 'disliked'] : Prediction --> 0
# ['phone', 'slim', 'light', 'display', 'beautiful'] : Prediction --> 1
# ['killer', 'expect', 'original', 'remotely', 'frightening'] : Prediction --> 1
# ['restaurant', 'clean', 'family', 'restaurant', 'feel'] : Prediction --> 1
# ['phone', 'slide', 'car', 'grip', 'prevents', 'phone', 'slipping', 'hand'] : Prediction --> 1
# ['point', 'journey', 'journey', 'touches', 'member', 'family'] : Prediction --> 1
# ['saw', 'film', 'recommend'] : Prediction --> 1
# ['place', 'awesome', 'want', 'light', 'healthy', 'summer'] : Prediction --> 1
# ['drinks', 'weak', 'people'] : Prediction --> 1
# ['minutes', 'film', 'started', 'having', 'second', 'thoughts'] : Prediction --> 0
# ['att', 'clear', 'sound', 'distorted', 'yell', 'talk'] : Prediction --> 1
# ['judith', 'light', 'favorite', 'actresses', 'think', 'superb', 'job', 'film'] : Prediction --> 1
# ['best', 'scene', 'movie', 'gerardo', 'trying', 'find', 'song', 'keeps', 'running', 'head'] : Prediction --> 1
# ['case', 'flimsy', 'piece', 'plastic', 'protection', 'whatsoever'] : Prediction --> 0
# ['service', 'exceptional', 'food', 'good', 'reviews'] : Prediction --> 1
# ['problem', 'thought', 'actor', 'playing', 'villain', 'low', 'rent', 'michael', 'ironside'] : Prediction --> 1
# ['average', 'acting', 'main', 'person', 'low', 'budget', 'clearly'] : Prediction --> 0
# ['basically', 'threw', 'money', 'window'] : Prediction --> 0
# ['chinese', 'forgeries', 'abound'] : Prediction --> 0
# ['boyfriend', 'tried', 'mediterranean', 'chicken', 'salad', 'fell', 'love'] : Prediction --> 1
# ['got', 'bored', 'watching', 'jessice', 'lange', 'clothes'] : Prediction --> 1
# ['voice', 'recognition', 'tremendous'] : Prediction --> 1
# ['miss'] : Prediction --> 1
# ['unfortunately', 'hit', 'bakery', 'leftover', 'day', 'ordered', 'stale'] : Prediction --> 0
# ['talk', 'hours', 'battery', 'literally', 'drained', 'dying'] : Prediction --> 0
# ['portable', 'works'] : Prediction --> 1
# ['recommend', 'confidence'] : Prediction --> 0
# ['got', 'enjoy', 'seafood', 'salad', 'fabulous', 'vinegrette'] : Prediction --> 0
# ['trust', 'website', 'expect', 'helpful', 'support'] : Prediction --> 0
# ['known', 'errol', 'flynn', 'brilliant', 'actor', 'dads', 'favourite', 'actor', 'grew', 'watching', 'films', 'child'] : Prediction --> 1
# ['sending'] : Prediction --> 0
# ['pale', 'color', 'instead', 'nice', 'char', 'flavor'] : Prediction --> 1
# ['like', 'reviewer', 'said', 'pay', 'eat', 'place'] : Prediction --> 0
# ['great', 'reception', 'time'] : Prediction --> 1
# ['like', 'loud', 'buzzing', 'override', 'conversations', 'phone'] : Prediction --> 0
# ['years', 'left', 'contract', 'hate', 'phone'] : Prediction --> 1
# ['insulted', 'felt', 'disrespected'] : Prediction --> 0
# ['service', 'terrible', 'food', 'mediocre'] : Prediction --> 0
# ['simply', 'disappointment'] : Prediction --> 0
# ['product', 'costs', 'expect', 'work', 'far', 'better', 'greater', 'ease', 'thing'] : Prediction --> 1
# ['awesome'] : Prediction --> 1
# ['trying', 'exercise', 'frustration'] : Prediction --> 0
# ['clipping', 'belt', 'deffinitely', 'feel', 'like', 'cent', 'coming'] : Prediction --> 0
# ['sat', 'minutes', 'finally', 'gave', 'left'] : Prediction --> 0
# ['company', 'joke'] : Prediction --> 0
# ['trouble', 'accessing', 'internet', 'downloading', 'ringtones', 'performing', 'functions'] : Prediction --> 0
# ['strike', 'wants', 'rushed'] : Prediction --> 0
# ['right', 'balance', 'war', 'love'] : Prediction --> 1
# ['good', 'service', 'check'] : Prediction --> 1
# ['shifting', 'bubbling', 'peeling', 'scratch', 'happier', 'new', 'droid'] : Prediction --> 1
# ['waiting', 'sure', 'item', 'work', 'recieve'] : Prediction --> 0
# ['work', 'listening', 'music', 'cingular'] : Prediction --> 0
# ['gotten', 'defect', 'risk', 'buying', 'built', 'quality'] : Prediction --> 0
# ['continuously', 'beautiful', 'look', 'bertolucci', 'relationships', 'convincing', 'narrative', 'engaging', 'master', 'work'] : Prediction --> 0
# ['ambiance', 'better'] : Prediction --> 1
# ['actors', 'truly', 'understand', 'particular', 'character', 'delivering', 'convincing', 'sincere', 'performance'] : Prediction --> 0
# ['food', 'arrived', 'quickly'] : Prediction --> 0
# ['wonderful', 'inspiring', 'watch', 'hope', 'gets', 'released', 'video', 'dvd'] : Prediction --> 1
# ['pretty', 'good', 'product'] : Prediction --> 1
# ['great', 'restaurant', 'mandalay', 'bay'] : Prediction --> 1
# ['mediocre', 'miserable', 'hollow', 'laughable', 'predictable', 'piece', 'garbage'] : Prediction --> 0
# ['bathrooms', 'location', 'seat', 'covers', 'replenished', 'plain', 'yucky'] : Prediction --> 0
# ['continue', 'come', 'ladies', 'night', 'andddd', 'date', 'night', 'highly', 'recommend', 'place', 'area'] : Prediction --> 1
# ['essentially', 'communications', 'tool', 'communicate'] : Prediction --> 1
# ['personally', 'love', 'hummus', 'pita', 'baklava', 'falafels', 'baba', 'ganoush', 'amazing', 'eggplant'] : Prediction --> 1
# ['thank', 'wasting', 'money'] : Prediction --> 0
# ['tried', 'cables', 'computer', 'ipod', 'works', 'fine'] : Prediction --> 1
# ['shower', 'area', 'outside', 'rinse', 'shower', 'mind', 'nude'] : Prediction --> 1
# ['obviously', 'problem', 'adhesive'] : Prediction --> 0
# ['stupid', 'thought', 'idea', 'volcano', 'los', 'angeles'] : Prediction --> 0
# ['dirty'] : Prediction --> 0
# ['found', 'beautiful', 'enjoyable', 'uplifting'] : Prediction --> 1
# ['patio', 'seating', 'comfortable'] : Prediction --> 1
# ['european', 'movie', 'nice', 'throwback', 'time', 'student', 'experiences', 'living', 'abroad', 'interacting', 'nationalities', 'circumstances', 'slightly', 'different'] : Prediction --> 1
# ['bt', 'headset', 'disapoinment'] : Prediction --> 1
# ['easy', 'watch'] : Prediction --> 1
# ['bad', 'characters', 'bad', 'story', 'bad', 'acting'] : Prediction --> 0
# ['recommend'] : Prediction --> 0
# ['ate', 'twice', 'visit', 'especially', 'enjoyed', 'salmon', 'salad'] : Prediction --> 1
# ['gotten', 'better', 'service', 'pizza', 'place', 'door', 'services', 'received', 'restaurant'] : Prediction --> 1
# ['run', 'new', 'battery', 'bars', 'days', 'charging'] : Prediction --> 0
# ['fits', 'surefire', 'perfectly'] : Prediction --> 1
# ['desserts', 'bit', 'strange'] : Prediction --> 0
# ['phone', 'great', 'pictures', 'video', 'clips'] : Prediction --> 1
# ['place', 'disgusting'] : Prediction --> 0
# ['wo', 'forget', 'movie'] : Prediction --> 0
# ['watching', 'washing', 'machine', 'twirling', 'hurt', 'eyes'] : Prediction --> 0
# ['group', 'claimed', 'handled', 'beautifully'] : Prediction --> 0
# ['structure', 'film', 'easily', 'tightly', 'constructed', 'history', 'cinema', 'think', 'film', 'vitally', 'important', 'occurs', 'minute', 'words', 'content', 'level', 'film', 'easily', 'fill', 'dozen', 'films', 'right', 'mind', 'ask', 'movie', 'simply', 'highest', 'superlative', 'form', 'cinema', 'imaginable', 'yes', 'film', 'require', 'significant', 'puzzle', 'solving', 'pieces', 'fit', 'create', 'beautiful', 'picture', 'short', 'film', 'certainly', 'pulls', 'punches', 'graphics', 'far', 'best', 'game', 'number', 'best', 'th', 'game', 'series', 'deserves', 'strong', 'love', 'insane', 'game', 'massive', 'levels', 'massive', 'unlockable', 'characters', 'massive', 'game', 'waste', 'money', 'game', 'kind', 'money', 'wasted', 'properly', 'actually', 'graphics', 'good', 'time', 'today', 'graphics', 'crap', 'canada', 'fun', 'game', 'aye', 'game', 'rocks', 'buy', 'play', 'enjoy', 'love', 'pure', 'brilliance', 'flick', 'doomed', 'conception', 'idea', 'lame', 'minor', 'character', 'mediocre', 'film', 'complete', 'non', 'sequel', 'changing', 'tone', 'pg', 'rated', 'family', 'movie', 'bit', 'interested', 'confirm', 'film', 'unfunny', 'generic', 'managed', 'away', 'entire', 'movie', 'exaggerating', 'moment', 'plot', 'point', 'joke', 'told', 'trailer', 'funny', 'talented', 'carrell', 'save', 'co', 'stars', 'fare', 'better', 'people', 'like', 'morgan', 'freeman', 'jonah', 'hill', 'ed', 'helms', 'wasted', 'story', 'predictable', 'lazy', 'real', 'effects', 'work', 'presence', 'animals', 'integration', 'scenes', 'worst', 'obvious', 'blue', 'green', 'screen', 'work', 'seen', 'cost', 'translate', 'quality', 'sure', 'film', 'succeeds', 'despite', 'obviously', 'meagre', 'budget', 'glad', 'film', 'obvious', 'choice', 'lesser', 'film', 'certainly', 'addition', 'having', 'lovely', 'songs', 'written', 'french', 'cancan', 'boasts', 'cutest', 'leading', 'ladies', 'grace', 'screen', 'hard', 'fall', 'head', 'heels', 'love', 'girl', 'negative', 'insipid', 'cause', 'regret', 'hours', 'life', 'wasted', 'screen', 'long', 'whiny', 'pointless', 'recommend', 'waiting', 'future', 'efforts', 'let', 'excellent', 'cast', 'story', 'line', 'performances', 'totally', 'believable', 'anne', 'heche', 'utterly', 'convincing', 'sam', 'shepard', 'portrayal', 'gung', 'ho', 'marine', 'sobering', 'sat', 'riveted', 'tv', 'screen', 'resounding', 'think', 'tom', 'hanks', 'good', 'actor', 'enjoyed', 'reading', 'book', 'children', 'little', 'disappointed', 'movie', 'character', 'totally', 'annoying', 'voice', 'gives', 'feeling', 'fingernails', 'chalkboard', 'totally', 'unnecessary', 'train', 'roller', 'coaster', 'scene', 'absolutely', 'warmth', 'charm', 'scenes', 'characters', 'movie', 'totally', 'grates', 'nerves', 'performances', 'improved', 'improvisation', 'actors', 'twice', 'worry', 'delivering', 'line', 'line', 'good', 'honestly', 'good', 'dialogue', 'follow', 'line', 'fit', 'surroundings', 'crackles', 'unpredictable', 'youthful', 'energy', 'honestly', 'found', 'hard', 'follow', 'concentrate', 'meanders', 'badly', 'generally', 'great', 'things', 'worth', 'hours', 'time', 'suspense', 'builders', 'good', 'cross', 'line', 'g', 'pg', 'especially', 'liked', 'non', 'cliche', 'choices', 'parents', 'movies', 'predict', 'dialog', 'verbatim', 'writing', 'movie', 'better', 'selections', 'want', 'movie', 'gross', 'gives', 'chills', 'great', 'choice', 'alexander', 'nevsky', 'great', 'film', 'amazing', 'film', 'artist', 'important', 'lived', 'glad', 'pretentious', 'piece', 's', 'planned', 'dodge', 'stratus', 'big', 'shots', 'gon', 'na', 'help', 'movie', 'makers', 'restrained', 'movie', 'business', 'québec'] : Prediction --> 1
# ['case', 'small', 'difficult', 'install'] : Prediction --> 0
# ['scared', 'horrified', 'sympathetic', 'characters', 'simply', 'annoying'] : Prediction --> 0
# ['instructions', 'explain', 'microphone', 'jack'] : Prediction --> 0
# ['seen', 'soap', 'operas', 'intelligent', 'movie'] : Prediction --> 0
# ['use', 'smallest', 'earpieces', 'provided', 'stays', 'pretty'] : Prediction --> 0
# ['great', 'touch'] : Prediction --> 1
# ['good', 'samsung'] : Prediction --> 1
# ['saw', 'child', 'tv', 'stranger', 'loved'] : Prediction --> 1
# ['kids', 'play', 'area', 'nasty'] : Prediction --> 0
# ['gave', 'trying', 'eat', 'crust', 'teeth', 'sore'] : Prediction --> 0
# ['place', 'way', 'overpriced', 'mediocre', 'food'] : Prediction --> 0
# ['piece', 'crap'] : Prediction --> 0
# ['seller', 'shipped', 'quickly', 'cheaper', 'competitors'] : Prediction --> 1

# %% [markdown]
# **25. Determine the accuracy for the test dataset, X_test/sample prediction, and train dataset**

# %%
# Determine accuracy on the test set
accuracy = accuracy_score(y_test, y_test_pred)
print(f"Test Set Accuracy: {accuracy * 100:.2f}%")

# Optionally, calculate accuracy on the training set
y_train_pred = pipe_countvect.predict(X_train)
train_accuracy = accuracy_score(y_train, y_train_pred)
print(f"Training Set Accuracy: {train_accuracy * 100:.2f}%")
# Out:
# Test Set Accuracy: 78.36%
# Training Set Accuracy: 98.54%
